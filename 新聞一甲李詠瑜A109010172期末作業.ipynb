# %% [markdown]
# <a href="https://colab.research.google.com/github/A109010172/Computational-Thinking-and-Program-Design/blob/main/%E6%96%B0%E8%81%9E%E4%B8%80%E7%94%B2%E6%9D%8E%E8%A9%A0%E7%91%9CA109010172%E6%9C%9F%E6%9C%AB%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 期末作業:少女養成遊戲 以身相許篇
#
# 組員:A109010016楊益慈 A109010034羅婄文 A109010172李詠瑜
#
# 腳本:
#
# 眼前剛醒來的少女:終於等到了，感謝你把我從黑暗的深淵中拯救出來，為了感謝你，讓我來當你的女朋友吧?
#
# 少女:男朋友先生，你想我怎樣稱呼你呢?勇者
#
# 少女:勇者，真是一個充滿正義感的名字。
#
# 少女:我覺得我本來的名字跟你的名字CP感不夠，你可以幫我再取一個嗎?人家要超可愛的名字喔~拜託你了:公主
#
# 公主:出現了!能賜予我如此不平凡的名字的人，果然你就是我的真命天子!
#
# 公主:勇者，不瞞你說，在我小的時候曾被魔族施了不幸的魔法，所以跟我在一起的話你也可能會遭遇到不幸。
#
# 公主:你願意跟這樣的我在一起嗎? (yes/no)yes
#
# 公主:哇!你簡直跟荔枝一樣，雖然外表不太好看，可是有着温柔的內心。
#
# 公主:那麼今天就是我們成為情侶的第一天，你打算帶我去哪裡呢?(遊樂場/電影院)遊樂場
#
# 場景:你們來到了迪迪尼樂園，公主迫不及待地拉你去排隊玩鬼屋。鬼屋裡面漆黑一片，你什麼也沒看見，這時候你感覺到有什麼抓住了你的腳跟
#
# 你會怎樣做呢?(叫女友幫忙看看/一腳踩下去)叫女友幫忙看看
#
# 公主轉過去看到了一個黑長髮的陰森女孩趴在地上用沾着血的手抓住了你的腳跟。
#
# 公主:你怎麼可以抓住我家男友的那個地方!
#
# 公主為了不讓其他女孩有碰到你腳跟的機會，她接下來一直抓住你的腳跟，直到走出鬼屋。
#
# 公主:肚子好餓喔…晚餐吃什麼啊?(荔枝宴/隨便)荔枝宴
#
# 公主:果然你最懂我了！
#
# 你們兩個手牽手去吃了一頓荔枝大餐後，從此幸福快樂的生活。
#
# 可喜可賀。
#
# 全劇終，恭喜達到完美結局。

# %%
print("眼前剛醒來的少女:終於等到了，感謝你把我從黑暗的深淵中拯救出來，為了感謝你，讓我來當你的女朋友吧?")
name=input("少女:男朋友先生，你想我怎樣稱呼你呢?")
print(f"少女:{name}，真是一個充滿正義感的名字。")
hername=input("少女:我覺得我本來的名字跟你的名字CP感不夠，你可以幫我再取一個嗎?人家要超可愛的名字喔~拜託你了:")
print(f"{hername}:出現了!能賜予我如此不平凡的名字的人，果然你就是我的真命天子!")
print(f"{hername}:{name}，不瞞你說，在我小的時候曾被魔族施了不幸的魔法，所以跟我在一起的話你也可能會遭遇到不幸。")
ans=input(f"{hername}:你願意跟這樣的我在一起嗎? (yes/no)")
if ans == "yes":
  print(f"{hername}:哇!你簡直跟荔枝一樣，雖然外表不太好看，可是有着温柔的內心。")
elif ans == "no":
  print(f"{hername}:哇嗚嗚嗚嗚嗚嗚嗚…你怎麼可以這樣拒絕人家，人家現在心靈受到極大的傷害喔！作為賠償，你務必陪在我身邊，不能拒絕！")
else:
  print(f"{hername}:雖然聽不懂你的回答，但你應該很樂意吧?我真是太瞭解你了。")
ans2=input(f"{hername}:那麼今天就是我們成為情侶的第一天，你打算帶我去哪裡呢?(遊樂場/電影院)")
if ans2 =="遊樂場":
 print(f"場景:你們來到了迪迪尼樂園，{hername}迫不及待地拉你去排隊玩鬼屋。鬼屋裡面漆黑一片，你什麼也沒看見，這時候你感覺到有什麼抓住了你的腳跟")
 ans3=input("你會怎樣做呢?(叫女友幫忙看看/一腳踩下去)")
 if ans3 =="叫女友幫忙看看":
  print(f"{hername}轉過去看到了一個黑長髮的陰森女孩趴在地上用沾着血的手抓住了你的腳跟。")
  print(f"{hername}:你怎麼可以抓住我家男友的那個地方!")
  print(f"{hername}為了不讓其他女孩有碰到你腳跟的機會，她接下來一直抓住你的腳跟，直到走出鬼屋。")
 elif ans3 =="一腳踩下去":
  print(f"{hername}露出了祟拜的眼神看着你")
  print(f"{hername}:你居然這麼快就打敗魔族的邪惡手下，太了不起了！")
  print("抓住你腳跟的工作人員痛得哇哇大叫，你們被趕出鬼屋了。")
 else:
   print(f"{hername}:我聽不懂你說什麼欸…我們先吃點什麼讓你補補腦子吧!")
elif ans2 =="電影院":
  print("場景:你們來到了一間豪華的電影院，正上映兩部電影，一部名叫「那些年，我們一起去過的廁所」，一部是「我的荔枝時代」")
  ans4=input("你想看哪部呢?(那些年，我們一起去過的廁所/我的荔枝時代)")
  if ans4 =="那些年，我們一起去過的廁所":
    print("電影開始播放了，內容是一群熱血沸騰的學生共同守護廁所的勵志故事。")
    print("你們愈看愈想上廁所，最後上廁所回來後電影就結束了。")
  elif ans4 =="我的荔枝時代":
    print("電影開始播放了，內容是男女主角與荔枝的三角關係")
    print("你們看完以後感到肚子餓了，兩人準備去吃晚餐。")
  else:
    print(f"{hername}:我聽不懂你說什麼欸…我們先吃點什麼讓你補補腦子吧!")
else:
  print(f"{hername}:我聽不懂你說什麼欸…我們先吃點什麼讓你補補腦子吧!")
ans5=input(f"{hername}:肚子好餓喔…晚餐吃什麼啊?(荔枝宴/隨便)")
if ans5 =="荔枝宴":
  print(f"{hername}:果然你最懂我了！")
  print("你們兩個手牽手去吃了一頓荔枝大餐後，從此幸福快樂的生活。")
  print("可喜可賀。")
  print("全劇終，恭喜達到完美結局。")
elif ans5 =="隨便":
  print(f"{hername}:我還以為…我們相處了這麼長的時間，你一定會懂我的…可是沒想到你居然這麼敷衍我…")
  print("系統提示:你的女友機器人已下線。")
  print("系統提示:恭喜獲得「憑本事單身」的榮譽。")
  print("遊戲結束。")
else:
  print(f"{hername}:你都不會好好回答問題是不是！分手吧！")
# Out:
# 眼前剛醒來的少女:終於等到了，感謝你把我從黑暗的深淵中拯救出來，為了感謝你，讓我來當你的女朋友吧?
# 少女:男朋友先生，你想我怎樣稱呼你呢?勇者
# 少女:勇者，真是一個充滿正義感的名字。
# 少女:我覺得我本來的名字跟你的名字CP感不夠，你可以幫我再取一個嗎?人家要超可愛的名字喔~拜託你了:公主
# 公主:出現了!能賜予我如此不平凡的名字的人，果然你就是我的真命天子!
# 公主:勇者，不瞞你說，在我小的時候曾被魔族施了不幸的魔法，所以跟我在一起的話你也可能會遭遇到不幸。
# 公主:你願意跟這樣的我在一起嗎? (yes/no)yes
# 公主:哇!你簡直跟荔枝一樣，雖然外表不太好看，可是有着温柔的內心。
# 公主:那麼今天就是我們成為情侶的第一天，你打算帶我去哪裡呢?(遊樂場/電影院)遊樂場
# 場景:你們來到了迪迪尼樂園，公主迫不及待地拉你去排隊玩鬼屋。鬼屋裡面漆黑一片，你什麼也沒看見，這時候你感覺到有什麼抓住了你的腳跟
# 你會怎樣做呢?(叫女友幫忙看看/一腳踩下去)叫女友幫忙看看
# 公主轉過去看到了一個黑長髮的陰森女孩趴在地上用沾着血的手抓住了你的腳跟。
# 公主:你怎麼可以抓住我家男友的那個地方!
# 公主為了不讓其他女孩有碰到你腳跟的機會，她接下來一直抓住你的腳跟，直到走出鬼屋。
# 公主:肚子好餓喔…晚餐吃什麼啊?(荔枝宴/隨便)荔枝宴
# 公主:果然你最懂我了！
# 你們兩個手牽手去吃了一頓荔枝大餐後，從此幸福快樂的生活。
# 可喜可賀。
# 全劇終，恭喜達到完美結局。
